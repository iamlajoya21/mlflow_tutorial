# %%
import mlflow
import mlflow.sklearn
import mlflow.xgboost
import mlflow.lightgbm
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split, ParameterSampler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, f1_score
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from scipy.stats import randint, uniform
import numpy as np

# %%
# Load dataset
data = load_iris()
X_train, X_test, y_train, y_test = train_test_split(data.data, data.target, test_size=0.2, random_state=42)

# Define hyperparameter grids for each model
param_grid_rf = {
    "n_estimators": randint(50, 200),
    "max_depth": randint(3, 10),
    "min_samples_split": randint(2, 10),
}

param_grid_xgb = {
    "n_estimators": randint(50, 200),
    "max_depth": randint(3, 10),
    "learning_rate": uniform(0.01, 0.3),
}

param_grid_lgbm = {
    "n_estimators": randint(50, 200),
    "max_depth": randint(3, 10),
    "learning_rate": uniform(0.01, 0.3),
}

# %%
# Define models
models = {
    "RandomForest": (RandomForestClassifier(random_state=42), param_grid_rf),
    "XGBoost": (XGBClassifier(random_state=42), param_grid_xgb),
    "LightGBM": (LGBMClassifier(random_state=42), param_grid_lgbm),
}

# Start MLflow experiment
mlflow.set_tracking_uri(uri="http://127.0.0.1:5000/")
mlflow.set_experiment("Iris Classification - All Parameter Sets")
# Out:
# 2025/03/11 22:39:49 INFO mlflow.tracking.fluent: Experiment with name 'Iris Classification - All Parameter Sets' does not exist. Creating a new experiment.
# <Experiment: artifact_location='mlflow-artifacts:/993075149469796631', creation_time=1741718389183, experiment_id='993075149469796631', last_update_time=1741718389183, lifecycle_stage='active', name='Iris Classification - All Parameter Sets', tags={}>

# %%
# Train, tune, and log models
for model_name, (model, param_grid) in models.items():
    # Generate parameter combinations
    param_combinations = list(ParameterSampler(param_grid, n_iter=10, random_state=42))

    for i, params in enumerate(param_combinations):
        with mlflow.start_run(run_name=f"{model_name}_ParamsSet_{i+1}"):
            # Set hyperparameters
            model.set_params(**params)

            # Train the model
            model.fit(X_train, y_train)

            # Evaluate the model
            y_pred = model.predict(X_test)
            accuracy = accuracy_score(y_test, y_pred)
            f1 = f1_score(y_test, y_pred, average="weighted")

            # Log metrics
            mlflow.log_metric("accuracy", accuracy)
            mlflow.log_metric("f1_score", f1)

            # Log hyperparameters
            mlflow.log_params(params)

            # Log the model
            if model_name == "RandomForest":
                mlflow.sklearn.log_model(model, model_name)
            elif model_name == "XGBoost":
                mlflow.xgboost.log_model(model, model_name)
            elif model_name == "LightGBM":
                mlflow.lightgbm.log_model(model, model_name)

            # Register the model
            model_uri = f"runs:/{mlflow.active_run().info.run_id}/{model_name}"
            registered_model = mlflow.register_model(model_uri, f"{model_name}_ParamsSet_{i+1}_IrisModel")
            print(f"Registered {model_name} - ParamsSet {i+1}: {registered_model.name}, Version: {registered_model.version}")
# Out:
# 2025/03/11 22:39:54 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# Successfully registered model 'RandomForest_ParamsSet_1_IrisModel'.
# 2025/03/11 22:39:54 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: RandomForest_ParamsSet_1_IrisModel, version 1
# Created version '1' of model 'RandomForest_ParamsSet_1_IrisModel'.
# Registered RandomForest - ParamsSet 1: RandomForest_ParamsSet_1_IrisModel, Version: 1
# 🏃 View run RandomForest_ParamsSet_1 at: http://127.0.0.1:5000/#/experiments/993075149469796631/runs/02b57b829bb34c01ad5a8af728f29a5e
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/993075149469796631
# ...
